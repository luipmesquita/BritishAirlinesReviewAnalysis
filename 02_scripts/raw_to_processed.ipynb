# %%
import pandas as pd

# %%
df = pd.read_csv('../01_data_files/airline_review_raw_data.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %%
df
# Out:
#       Unnamed: 0  rating                            header  \
# 0              0       2      service was mediocre at best
# 1              1       2  BA standards continue to decline
# 2              2       2      won the race to the bottom"
# 3              3       3            Not a reliable airline
# 4              4       1         It is a national disgrace
# ...          ...     ...                               ...
# 3611        3649       2   British Airways customer review
# 3612        3650       8   British Airways customer review
# 3613        3651       8   British Airways customer review
# 3614        3652       6   British Airways customer review
# 3615        3653       8   British Airways customer review
#
#                    author        date           place  \
# 0             Gary Storer  2023-10-03  United Kingdom
# 1                A Jensen  2023-10-02  United Kingdom
# 2            John Rockett  2023-10-02  United Kingdom
# ...

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'rating', 'header', 'author', 'date', 'place',
#        'content', 'aircraft', 'traveller_type', 'seat_type', 'route',
#        'date_flown', 'seat_comfort', 'cabin_staff_service',
#        'food_beverages', 'ground_service', 'value_for_money',
#        'recommended', 'entertainment', 'trip_verified'], dtype=object)

# %%
new_columns = ['id', 'rating', 'header', 'author', 'date', 'place',
       'content', 'aircraft', 'traveller_type', 'seat_type', 'route',
       'date_flown', 'seat_comfort', 'cabin_staff_service',
       'food_beverages', 'ground_service', 'value_for_money',
       'recommended', 'entertainment', 'trip_verified']

# %%
df.columns = new_columns

# %%
df
# Out:
#         id  rating                            header               author  \
# 0        0       2      service was mediocre at best          Gary Storer
# 1        1       2  BA standards continue to decline             A Jensen
# 2        2       2      won the race to the bottom"          John Rockett
# 3        3       3            Not a reliable airline  Tatiana Bobrovskaya
# 4        4       1         It is a national disgrace             A Dawson
# ...    ...     ...                               ...                  ...
# 3611  3649       2   British Airways customer review             G Pardoe
# 3612  3650       8   British Airways customer review           Guy Senior
# 3613  3651       8   British Airways customer review          Jack Hughes
# 3614  3652       6   British Airways customer review             W Benson
# 3615  3653       8   British Airways customer review    Michael Dielissen
#
#             date           place  \
# 0     2023-10-03  United Kingdom
# ...

# %%
for i in range(df.shape[0]):
    trimmed_content = ""
    trimmed_header = ""
    trimmed_content = df.values[i][6].strip()
    trimmed_header = df.values[i][2].strip()
    df['content'] = df['content'].replace([df.values[i][6]], trimmed_content)
    df['header'] = df['header'].replace([df.values[i][2]], trimmed_header)

# %%
df.to_csv('../01_data_files/airline_review_processed_1.csv')
